# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/startup_funding.csv') #reading startup funding dataset

# %%
df.head() #It returns first 5 rows of the dataset
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01-08-2017      TouchKin         Technology
# 1    1  02-08-2017       Ethinos         Technology
# 2    2  02-08-2017  Leverage Edu  Consumer Internet
# 3    3  02-08-2017          Zepo  Consumer Internet
# 4    4  02-08-2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# 2  Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                     Narottam Thudi, Shireesh Palle    Seed Funding
#
#   AmountInUSD Remarks
# 0   13,00,000     NaN
# 1         NaN     NaN
# 2         NaN     NaN
# 3    5,00,000     NaN
# 4    8,50,000     NaN

# %%
df.info() #returns column names,non null count and datatypes of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2372 entries, 0 to 2371
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SNo               2372 non-null   int64
#  1   Date              2372 non-null   object
#  2   StartupName       2372 non-null   object
#  3   IndustryVertical  2201 non-null   object
#  4   SubVertical       1436 non-null   object
#  5   CityLocation      2193 non-null   object
#  6   InvestorsName     2364 non-null   object
#  7   InvestmentType    2371 non-null   object
#  8   AmountInUSD       1525 non-null   object
#  9   Remarks           419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 185.4+ KB

# %%
df.describe(include='all')
# Out:
#                 SNo        Date StartupName   IndustryVertical  \
# count   2372.000000        2372        2372               2201
# unique          NaN         698        2001                743
# top             NaN  02-02-2015      Swiggy  Consumer Internet
# freq            NaN          11           7                772
# mean    1185.500000         NaN         NaN                NaN
# std      684.881742         NaN         NaN                NaN
# min        0.000000         NaN         NaN                NaN
# 25%      592.750000         NaN         NaN                NaN
# 50%     1185.500000         NaN         NaN                NaN
# 75%     1778.250000         NaN         NaN                NaN
# max     2371.000000         NaN         NaN                NaN
#
#             SubVertical CityLocation          InvestorsName InvestmentType  \
# count              1436         2193                   2364           2371
# unique             1364           71                   1885              7
# top     Online Pharmacy    Bangalore  Undisclosed Investors   Seed Funding
# freq                  9          627                     33           1271
# mean                NaN          NaN                    NaN            NaN
# std                 NaN          NaN                    NaN            NaN
# min                 NaN          NaN                    NaN            NaN
# 25%                 NaN          NaN                    NaN            NaN
# 50%                 NaN          NaN                    NaN            NaN
# 75%                 NaN          NaN                    NaN            NaN
# max                 NaN          NaN                    NaN            NaN
#
#        AmountInUSD   Remarks
# count         1525       419
# unique         328        69
# top      10,00,000  Series A
# freq           130       177
# mean           NaN       NaN
# std            NaN       NaN
# min            NaN       NaN
# 25%            NaN       NaN
# 50%            NaN       NaN
# 75%            NaN       NaN
# max            NaN       NaN

# %%
df.columns
# Out:
# Index(['SNo', 'Date', 'StartupName', 'IndustryVertical', 'SubVertical',
#        'CityLocation', 'InvestorsName', 'InvestmentType', 'AmountInUSD',
#        'Remarks'],
#       dtype='object')

# %%
df=df.drop(columns={'SNo','StartupName','InvestorsName'}) #Dropped non important columns
df
# Out:
#             Date   IndustryVertical  \
# 0     01-08-2017         Technology
# 1     02-08-2017         Technology
# 2     02-08-2017  Consumer Internet
# 3     02-08-2017  Consumer Internet
# 4     02-08-2017  Consumer Internet
# ...          ...                ...
# 2367  29-01-2015                NaN
# 2368  29-01-2015                NaN
# 2369  30-01-2015                NaN
# 2370  30-01-2015                NaN
# 2371  31-01-2015                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# 2     Online platform for Higher Education Services    New Delhi
# 3                            DIY Ecommerce platform       Mumbai
# 4                     healthcare service aggregator    Hyderabad
# ...                                             ...          ...
# 2367                                            NaN          NaN
# 2368                                            NaN          NaN
# 2369                                            NaN          NaN
# 2370                                            NaN          NaN
# 2371                                            NaN          NaN
#
#       InvestmentType AmountInUSD                            Remarks
# 0     Private Equity   13,00,000                                NaN
# 1     Private Equity         NaN                                NaN
# 2       Seed Funding         NaN                                NaN
# 3       Seed Funding    5,00,000                                NaN
# 4       Seed Funding    8,50,000                                NaN
# ...              ...         ...                                ...
# 2367  Private Equity   45,00,000                                NaN
# 2368  Private Equity    8,25,000                Govt backed VC Fund
# 2369  Private Equity   15,00,000                                NaN
# 2370  Private Equity         NaN  Strategic Funding, Minority stake
# 2371    Seed Funding    1,40,000                                NaN
#
# [2372 rows x 7 columns]

# %%
df['Funded']=df['AmountInUSD'].notnull().astype(int) #Labelled startup is funded or not

# %%
df
# Out:
#             Date   IndustryVertical  \
# 0     01-08-2017         Technology
# 1     02-08-2017         Technology
# 2     02-08-2017  Consumer Internet
# 3     02-08-2017  Consumer Internet
# 4     02-08-2017  Consumer Internet
# ...          ...                ...
# 2367  29-01-2015                NaN
# 2368  29-01-2015                NaN
# 2369  30-01-2015                NaN
# 2370  30-01-2015                NaN
# 2371  31-01-2015                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# 2     Online platform for Higher Education Services    New Delhi
# 3                            DIY Ecommerce platform       Mumbai
# 4                     healthcare service aggregator    Hyderabad
# ...                                             ...          ...
# 2367                                            NaN          NaN
# 2368                                            NaN          NaN
# 2369                                            NaN          NaN
# 2370                                            NaN          NaN
# 2371                                            NaN          NaN
#
#       InvestmentType AmountInUSD                            Remarks  Funded
# 0     Private Equity   13,00,000                                NaN       1
# 1     Private Equity         NaN                                NaN       0
# 2       Seed Funding         NaN                                NaN       0
# 3       Seed Funding    5,00,000                                NaN       1
# 4       Seed Funding    8,50,000                                NaN       1
# ...              ...         ...                                ...     ...
# 2367  Private Equity   45,00,000                                NaN       1
# 2368  Private Equity    8,25,000                Govt backed VC Fund       1
# 2369  Private Equity   15,00,000                                NaN       1
# 2370  Private Equity         NaN  Strategic Funding, Minority stake       0
# 2371    Seed Funding    1,40,000                                NaN       1
#
# [2372 rows x 8 columns]

# %%
df
# Out:
#             Date   IndustryVertical  \
# 0     01-08-2017         Technology
# 1     02-08-2017         Technology
# 2     02-08-2017  Consumer Internet
# 3     02-08-2017  Consumer Internet
# 4     02-08-2017  Consumer Internet
# ...          ...                ...
# 2367  29-01-2015                NaN
# 2368  29-01-2015                NaN
# 2369  30-01-2015                NaN
# 2370  30-01-2015                NaN
# 2371  31-01-2015                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# 2     Online platform for Higher Education Services    New Delhi
# 3                            DIY Ecommerce platform       Mumbai
# 4                     healthcare service aggregator    Hyderabad
# ...                                             ...          ...
# 2367                                            NaN          NaN
# 2368                                            NaN          NaN
# 2369                                            NaN          NaN
# 2370                                            NaN          NaN
# 2371                                            NaN          NaN
#
#       InvestmentType AmountInUSD                            Remarks  Funded
# 0     Private Equity   13,00,000                                NaN       1
# 1     Private Equity         NaN                                NaN       0
# 2       Seed Funding         NaN                                NaN       0
# 3       Seed Funding    5,00,000                                NaN       1
# 4       Seed Funding    8,50,000                                NaN       1
# ...              ...         ...                                ...     ...
# 2367  Private Equity   45,00,000                                NaN       1
# 2368  Private Equity    8,25,000                Govt backed VC Fund       1
# 2369  Private Equity   15,00,000                                NaN       1
# 2370  Private Equity         NaN  Strategic Funding, Minority stake       0
# 2371    Seed Funding    1,40,000                                NaN       1
#
# [2372 rows x 8 columns]

# %%
df.isnull().sum() #checked for null values in each column
# Out:
# Date                   0
# IndustryVertical     171
# SubVertical          936
# CityLocation         179
# InvestmentType         1
# AmountInUSD          847
# Remarks             1953
# Funded                 0
# dtype: int64

# %%
df.shape  #returns number of rows and columns
# Out:
# (2372, 8)

# %%
def missing_value_report(df):
    missing_count = df.isnull().sum()
    missing_percentage=(missing_count/len(df)) *100.
    report=pd.DataFrame({
        'Missing values':missing_count,
        'Missing percentage':missing_percentage.round(2)
    })
    return report[report['Missing values']>0].sort_values(by='Missing percentage',ascending=False)
print(missing_value_report(df))
# Out:
#                   Missing values  Missing percentage
# Remarks                     1953               82.34
# SubVertical                  936               39.46
# AmountInUSD                  847               35.71
# CityLocation                 179                7.55
# IndustryVertical             171                7.21
# InvestmentType                 1                0.04

# %%
#Data cleaning

# %%
df.drop(columns=['Remarks'],inplace=True) #Dropped remarks column, not an important column
df.drop(columns=['SubVertical'],inplace=True) #Dropped subvertical column, too messy

# %%
df['InvestmentType'].fillna(df['InvestmentType'].mode()[0],inplace=True) #One value missing,filled with mode
# Out:
# /tmp/ipython-input-132-4286017681.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['InvestmentType'].fillna(df['InvestmentType'].mode()[0],inplace=True) #One value missing,filled with mode

# %%
df.dropna(subset=['IndustryVertical','CityLocation'],inplace=True)  #Dropped missing values

# %%
df.isnull().sum()
# Out:
# Date                  0
# IndustryVertical      0
# CityLocation          0
# InvestmentType        0
# AmountInUSD         803
# Funded                0
# dtype: int64

# %%
df
# Out:
#             Date            IndustryVertical CityLocation  InvestmentType  \
# 0     01-08-2017                  Technology    Bangalore  Private Equity
# 1     02-08-2017                  Technology       Mumbai  Private Equity
# 2     02-08-2017           Consumer Internet    New Delhi    Seed Funding
# 3     02-08-2017           Consumer Internet       Mumbai    Seed Funding
# 4     02-08-2017           Consumer Internet    Hyderabad    Seed Funding
# ...          ...                         ...          ...             ...
# 2196  29-04-2015  Startup Analytics platform    Bangalore  Private Equity
# 2197  29-04-2015    Mobile Food Ordering app    Bangalore    Seed Funding
# 2198  29-04-2015  Financial Markets Software    Bangalore    Seed Funding
# 2199  29-04-2015   Hiring Analytics platform      Chennai    Seed Funding
# 2200  29-04-2015   Online Travel Marketplace        Noida  Private Equity
#
#      AmountInUSD  Funded
# 0      13,00,000       1
# 1            NaN       0
# 2            NaN       0
# 3       5,00,000       1
# 4       8,50,000       1
# ...          ...     ...
# 2196   35,00,000       1
# 2197         NaN       0
# 2198    4,00,000       1
# 2199    5,00,000       1
# 2200   80,00,000       1
#
# [2193 rows x 6 columns]

# %%
#df['Date']=pd.to_datetime(df['Date'], errors='coerce')
#df['year']=df['Date'].dt.year
#df['Month']=df['Date'].dt.month
#df['Quarter']=df['Date'].dt.quarter
#df.drop(columns=['Date'], inplace=True)

# %%
#df.dropna(subset=['year','Month','Quarter'],inplace=True)  #Dropped missing values

# %%
df_encode=pd.get_dummies(df,columns=['CityLocation','IndustryVertical','InvestmentType'],drop_first=True) #applied one hot encoding

# %%
df_encode
# Out:
#             Date AmountInUSD  Funded  CityLocation_Ahmedabad  \
# 0     01-08-2017   13,00,000       1                   False
# 1     02-08-2017         NaN       0                   False
# 2     02-08-2017         NaN       0                   False
# 3     02-08-2017    5,00,000       1                   False
# 4     02-08-2017    8,50,000       1                   False
# ...          ...         ...     ...                     ...
# 2196  29-04-2015   35,00,000       1                   False
# 2197  29-04-2015         NaN       0                   False
# 2198  29-04-2015    4,00,000       1                   False
# 2199  29-04-2015    5,00,000       1                   False
# 2200  29-04-2015   80,00,000       1                   False
#
#       CityLocation_Bangalore  CityLocation_Bangalore / Palo Alto  \
# 0                       True                               False
# 1                      False                               False
# 2                      False                               False
# 3                      False                               False
# 4                      False                               False
# ...                      ...                                 ...
# 2196                    True                               False
# 2197                    True                               False
# 2198                    True                               False
# 2199                   False                               False
# 2200                   False                               False
#
#       CityLocation_Bangalore / SFO  CityLocation_Bangalore / San Mateo  \
# 0                            False                               False
# 1                            False                               False
# 2                            False                               False
# 3                            False                               False
# 4                            False                               False
# ...                            ...                                 ...
# 2196                         False                               False
# 2197                         False                               False
# 2198                         False                               False
# 2199                         False                               False
# 2200                         False                               False
#
#       CityLocation_Bangalore / USA  CityLocation_Bangalore/ Bangkok  ...  \
# 0                            False                            False  ...
# 1                            False                            False  ...
# 2                            False                            False  ...
# 3                            False                            False  ...
# 4                            False                            False  ...
# ...                            ...                              ...  ...
# 2196                         False                            False  ...
# 2197                         False                            False  ...
# 2198                         False                            False  ...
# 2199                         False                            False  ...
# 2200                         False                            False  ...
#
#       IndustryVertical_pre-owned Luxury online apparel seller  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_pre-used apparel shopping mobile app  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_pre-used luxury item Marketplace  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_proximity marketing & Mobile Advertising platform  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_residential rental management platform  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_solar products and services marketplace  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_virtual reality, 3d simulation and stereoscopic products  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_visual search and discovery platform  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       InvestmentType_Private Equity  InvestmentType_Seed Funding
# 0                              True                        False
# 1                              True                        False
# 2                             False                         True
# 3                             False                         True
# 4                             False                         True
# ...                             ...                          ...
# 2196                           True                        False
# 2197                          False                         True
# 2198                          False                         True
# 2199                          False                         True
# 2200                           True                        False
#
# [2193 rows x 814 columns]

# %%
df.columns
# Out:
# Index(['Date', 'IndustryVertical', 'CityLocation', 'InvestmentType',
#        'AmountInUSD', 'Funded'],
#       dtype='object')

# %%
x=df_encode.drop(columns=['AmountInUSD','Funded','Date']) #we didn't include AmountInUSD,it may cause direct data leakage
y=df_encode['Funded']

# %%
x
# Out:
#       CityLocation_Ahmedabad  CityLocation_Bangalore  \
# 0                      False                    True
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 4                      False                   False
# ...                      ...                     ...
# 2196                   False                    True
# 2197                   False                    True
# 2198                   False                    True
# 2199                   False                   False
# 2200                   False                   False
#
#       CityLocation_Bangalore / Palo Alto  CityLocation_Bangalore / SFO  \
# 0                                  False                         False
# 1                                  False                         False
# 2                                  False                         False
# 3                                  False                         False
# 4                                  False                         False
# ...                                  ...                           ...
# 2196                               False                         False
# 2197                               False                         False
# 2198                               False                         False
# 2199                               False                         False
# 2200                               False                         False
#
#       CityLocation_Bangalore / San Mateo  CityLocation_Bangalore / USA  \
# 0                                  False                         False
# 1                                  False                         False
# 2                                  False                         False
# 3                                  False                         False
# 4                                  False                         False
# ...                                  ...                           ...
# 2196                               False                         False
# 2197                               False                         False
# 2198                               False                         False
# 2199                               False                         False
# 2200                               False                         False
#
#       CityLocation_Bangalore/ Bangkok  CityLocation_Belgaum  \
# 0                               False                 False
# 1                               False                 False
# 2                               False                 False
# 3                               False                 False
# 4                               False                 False
# ...                               ...                   ...
# 2196                            False                 False
# 2197                            False                 False
# 2198                            False                 False
# 2199                            False                 False
# 2200                            False                 False
#
#       CityLocation_Bhopal  CityLocation_Boston  ...  \
# 0                   False                False  ...
# 1                   False                False  ...
# 2                   False                False  ...
# 3                   False                False  ...
# 4                   False                False  ...
# ...                   ...                  ...  ...
# 2196                False                False  ...
# 2197                False                False  ...
# 2198                False                False  ...
# 2199                False                False  ...
# 2200                False                False  ...
#
#       IndustryVertical_pre-owned Luxury online apparel seller  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_pre-used apparel shopping mobile app  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_pre-used luxury item Marketplace  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_proximity marketing & Mobile Advertising platform  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_residential rental management platform  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_solar products and services marketplace  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_virtual reality, 3d simulation and stereoscopic products  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       IndustryVertical_visual search and discovery platform  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2196                                              False
# 2197                                              False
# 2198                                              False
# 2199                                              False
# 2200                                              False
#
#       InvestmentType_Private Equity  InvestmentType_Seed Funding
# 0                              True                        False
# 1                              True                        False
# 2                             False                         True
# 3                             False                         True
# 4                             False                         True
# ...                             ...                          ...
# 2196                           True                        False
# 2197                          False                         True
# 2198                          False                         True
# 2199                          False                         True
# 2200                           True                        False
#
# [2193 rows x 811 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 2196    1
# 2197    0
# 2198    1
# 2199    1
# 2200    1
# Name: Funded, Length: 2193, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42) #train_test_split

# %%
#Applying Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix
lr_model=LogisticRegression(max_iter=1000)
lr_model.fit(X_train,y_train)
y_pred_lr=lr_model.predict(X_test)

#Evaluate
print("Logistic Regression")
print(confusion_matrix(y_test,y_pred_lr))
print(classification_report(y_test,y_pred_lr))
# Out:
# Logistic Regression
# [[ 37 138]
#  [ 34 230]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.21      0.30       175
#            1       0.62      0.87      0.73       264
#
#     accuracy                           0.61       439
#    macro avg       0.57      0.54      0.51       439
# weighted avg       0.58      0.61      0.56       439

# %%
coef=pd.DataFrame({'Feature':X_train.columns,'Coefficient' :lr_model.coef_[0]})
coef=coef.sort_values(by='Coefficient',key=abs,ascending=False)
print(coef.head(10))
# Out:
#                                                Feature  Coefficient
# 312                        IndustryVertical_Healthcare    -1.604062
# 139     IndustryVertical_Car & Bike ecommerce platform    -1.142084
# 31                                  CityLocation_Kochi    -0.827437
# 26                                 CityLocation_Jaipur    -0.792674
# 526            IndustryVertical_Online Hiring Platform    -0.785711
# 377  IndustryVertical_Interface development platfor...    -0.785711
# 702      IndustryVertical_Speech Recognition Solutions    -0.732432
# 472  IndustryVertical_On-Demand Laundry & Dry clean...    -0.732432
# 168  IndustryVertical_Content Management Software S...    -0.732432
# 770  IndustryVertical_bus ticketing and fleet manag...    -0.731410

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model= RandomForestClassifier(random_state=42)
rf_model.fit(X_train,y_train)
y_pred_rf=rf_model.predict(X_test)

#Evaluate
print("RanomForestClassifier")
print(confusion_matrix(y_test,y_pred_rf))
print(classification_report(y_test,y_pred_rf))
# Out:
# RanomForestClassifier
# [[ 52 123]
#  [ 64 200]]
#               precision    recall  f1-score   support
#
#            0       0.45      0.30      0.36       175
#            1       0.62      0.76      0.68       264
#
#     accuracy                           0.57       439
#    macro avg       0.53      0.53      0.52       439
# weighted avg       0.55      0.57      0.55       439

# %%
top_n=20
important=rf_model.feature_importances_
feat_imp=pd.DataFrame({'Feature':X_train.columns,'Importancee':important})
feat_imp=feat_imp.sort_values(by='Importancee',ascending=False).head(top_n)
print(feat_imp.head(10))
# Out:
#                                 Feature  Importancee
# 809       InvestmentType_Private Equity     0.070040
# 810         InvestmentType_Seed Funding     0.064372
# 164  IndustryVertical_Consumer Internet     0.025922
# 726         IndustryVertical_Technology     0.023899
# 312         IndustryVertical_Healthcare     0.020108
# 775          IndustryVertical_eCommerce     0.014828
# 42               CityLocation_New Delhi     0.013586
# 1                CityLocation_Bangalore     0.012879
# 217          IndustryVertical_ECommerce     0.012250
# 26                  CityLocation_Jaipur     0.011955

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.barh(feat_imp['Feature'],feat_imp['Importancee'])
plt.gca().invert_yaxis()
plt.title("Feature Importance Random Forest")
plt.xlabel("Important score")
plt.show()

# %%
#CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score
rf_scores=cross_val_score(rf_model,X_train,y_train,cv=5,scoring='f1')
print("Random forest F1 scores :",rf_scores)
print("Random forest Avg F1 score :",rf_scores.mean())
# Out:
# Random forest F1 scores : [0.68803419 0.73500967 0.71372549 0.67982456 0.72      ]
# Random forest Avg F1 score : 0.7073187821627318

# %%
#Logistic Regression

# %%
lr_scores = cross_val_score(lr_model,X_train,y_train,cv=5,scoring='f1')
print("Logistic Regression F1 scores:",lr_scores)
print("Logistic Regression Avg F1 scores",lr_scores.mean())
# Out:
# Logistic Regression F1 scores: [0.736      0.76865672 0.74285714 0.75048356 0.76679842]
# Logistic Regression Avg F1 scores 0.7529591674483165

# %%
#HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV  #Define the parameter grid
param_grid = {
    'n_estimators' :[50,100,200],
    'max_depth' :[None,10,20],
    'min_samples_split' :[2,5],
    'min_samples_leaf' : [1,2]

}
rf_tuned = RandomForestClassifier(random_state=42) #model created
grid_search = GridSearchCV(estimator=rf_tuned,param_grid=param_grid,cv=5,scoring='f1',verbose=1,n_jobs=-1) #Use all CPU scores
grid_search.fit(X_train,y_train)
best_rf=grid_search.best_estimator_
print("Best Parameters :",grid_search.best_params_)
print("Best F1 score from CV :",grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best Parameters : {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best F1 score from CV : 0.7853604991086465

# %%
#Evaluate tuned model on test set

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,f1_score
y_pred = best_rf.predict(X_test)

print("Accuracy :",accuracy_score(y_test,y_pred))
print("F1 score :",f1_score(y_test,y_pred))
print("Classification Report :]\n",classification_report(y_test,y_pred))
print("Confusion Matrix :\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy : 0.5968109339407744
# F1 score : 0.743849493487699
# Classification Report :]
#                precision    recall  f1-score   support
#
#            0       0.42      0.03      0.05       175
#            1       0.60      0.97      0.74       264
#
#     accuracy                           0.60       439
#    macro avg       0.51      0.50      0.40       439
# weighted avg       0.53      0.60      0.47       439
#
# Confusion Matrix :
#  [[  5 170]
#  [  7 257]]
